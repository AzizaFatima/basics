# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
d1={"age":[10,20,30,40,50],"salary":[7888,89344,783234,350000,40000]}

# %%
d1
# Out:
# {'age': [10, 20, 30, 40, 50], 'salary': [7888, 89344, 783234, 350000, 40000]}

# %%
df1=pd.DataFrame(d1)

# %%
df1
# Out:
#    age  salary
# 0   10    7888
# 1   20   89344
# 2   30  783234
# 3   40  350000
# 4   50   40000

# %%
df=pd.read_csv("Salaries.csv")

# %%
df
# Out:
#          rank discipline  phd  service  gender  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-00cf07b74dcd> in <cell line: 1>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df.tail() # gives information of Last Five Rows
# Out:
#          rank discipline  phd  service  gender  salary
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646

# %%
df.head() # gives information of first five Rows
# Out:
#    rank discipline  phd  service gender  salary
# 0  Prof          B   56       49   Male  186960
# 1  Prof          A   12        6   Male   93000
# 2  Prof          A   23       20   Male  110515
# 3  Prof          A   40       31   Male  131205
# 4  Prof          B   20       18   Male  104800

# %%
df.dtypes # datatypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# gender        object
# salary         int64
# dtype: object

# %%
col=df.columns # get Column Names

# %%
col
# Out:
# Index(['rank', 'discipline', 'phd', 'service', 'gender', 'salary'], dtype='object')

# %%
df.shape # gives output of number of Rows and Columns
# Out:
# (78, 6)

# %%
df.info # information about the DataFrame
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-6a0acb306124> in <cell line: 1>()
# ----> 1 df.info # information about the DataFrame
#
# NameError: name 'df' is not defined

# %% [markdown]
# Accessing of Columns

# %%
df["rank"]
# Out:
# 0          Prof
# 1          Prof
# 2          Prof
# 3          Prof
# 4          Prof
#         ...
# 73         Prof
# 74    AssocProf
# 75         Prof
# 76         Prof
# 77         Prof
# Name: rank, Length: 78, dtype: object

# %%
# Accessing multiple column as a list

# %%
df[["rank","phd","salary","gender"]]
# Out:
#          rank  phd  salary  gender
# 0        Prof   56  186960    Male
# 1        Prof   12   93000    Male
# 2        Prof   23  110515    Male
# 3        Prof   40  131205    Male
# 4        Prof   20  104800    Male
# ..        ...  ...     ...     ...
# 73       Prof   18  105450  Female
# 74  AssocProf   19  104542  Female
# 75       Prof   17  124312  Female
# 76       Prof   28  109954  Female
# 77       Prof   23  109646  Female
#
# [78 rows x 4 columns]

# %%
df[["rank","salary","gender"]]
# Out:
#          rank  salary  gender
# 0        Prof  186960    Male
# 1        Prof   93000    Male
# 2        Prof  110515    Male
# 3        Prof  131205    Male
# 4        Prof  104800    Male
# ..        ...     ...     ...
# 73       Prof  105450  Female
# 74  AssocProf  104542  Female
# 75       Prof  124312  Female
# 76       Prof  109954  Female
# 77       Prof  109646  Female
#
# [78 rows x 3 columns]

# %%
#geting  columns of information by giving condition on gender
df[df["gender"]=="Female"]
# Out:
#          rank discipline  phd  service  gender  salary
# 39       Prof          B   18       18  Female  129000
# 40       Prof          A   39       36  Female  137000
# 41  AssocProf          A   13        8  Female   74830
# 42   AsstProf          B    4        2  Female   80225
# 43   AsstProf          B    5        0  Female   77000
# 44       Prof          B   23       19  Female  151768
# 45       Prof          B   25       25  Female  140096
# 46   AsstProf          B   11        3  Female   74692
# 47  AssocProf          B   11       11  Female  103613
# 48       Prof          B   17       17  Female  111512
# 49       Prof          B   17       18  Female  122960
# 50   AsstProf          B   10        5  Female   97032
# 51       Prof          B   20       14  Female  127512
# 52       Prof          A   12        0  Female  105000
# 53   AsstProf          A    5        3  Female   73500
# 54  AssocProf          A   25       22  Female   62884
# ...

# %%
df[df["discipline"]=="AssociateProf"]
# Out:
# Empty DataFrame
# Columns: [rank, discipline, phd, service, gender, salary]
# Index: []

# %%
df["rank"]
# Out:
# 0          Prof
# 1          Prof
# 2          Prof
# 3          Prof
# 4          Prof
#         ...
# 73         Prof
# 74    AssocProf
# 75         Prof
# 76         Prof
# 77         Prof
# Name: rank, Length: 78, dtype: object

# %%
df.head()
# Out:
#    rank discipline  phd  service gender  salary
# 0  Prof          B   56       49   Male  186960
# 1  Prof          A   12        6   Male   93000
# 2  Prof          A   23       20   Male  110515
# 3  Prof          A   40       31   Male  131205
# 4  Prof          B   20       18   Male  104800
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def histogram(df, colname, num_bins=20, figscale=1):
#   from matplotlib import pyplot as plt
#   df[colname].plot(kind='hist', bins=num_bins, title=colname, figsize=(8*figscale, 4*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = histogram(_df_0, *['phd'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# ...

# %%
df[df.columns([0,1,2],axis=1)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-2630d32f248a> in <cell line: 1>()
# ----> 1 df[df.columns([0,1,2],axis=1)]
#
# TypeError: 'Index' object is not callable

# %%
#get all records from DataFrame where salary is gretaer than 10000

# %%
df[df["salary"]>10000]
# Out:
#          rank discipline  phd  service  gender  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df[["rank","discipline","salary"]][df["salary"]>10000]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-99-b77752ef59c4> in <cell line: 1>()
# ----> 1 df[["rank","discipline","salary"]][df["salary"]>10000]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3811             if is_iterator(key):
#    3812                 key = list(key)
# -> 3813             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3814
#    3815         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6068             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6069
# -> 6070         self._raise_if_missing(keyarr, indexer, axis_name)
#    6071
#    6072         keyarr = self.take(indexer)
#
# ...

# %%
df[df[[0,1,2,3,4]]]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-69-d63dbdb1251b> in <cell line: 1>()
# ----> 1 df[df[[0,1,2,3,4]]]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in __getitem__(self, key)
#    3811             if is_iterator(key):
#    3812                 key = list(key)
# -> 3813             indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3814
#    3815         # take() does not accept boolean indexers
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in _get_indexer_strict(self, key, axis_name)
#    6068             keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
#    6069
# -> 6070         self._raise_if_missing(keyarr, indexer, axis_name)
#    6071
#    6072         keyarr = self.take(indexer)
#
# ...

# %%
df.iloc()

# %%
df.iloc[5:10]
# Out:
#         rank discipline  phd  service gender  salary
# 5       Prof          A   20       20   Male  122400
# 6  AssocProf          A   20       17   Male   81285
# 7       Prof          A   18       18   Male  126300
# 8       Prof          A   29       19   Male   94350
# 9       Prof          A   51       51   Male   57800

# %%
df.iloc[0:1]
# Out:
#    rank discipline  phd  service gender  salary
# 0  Prof          B   56       49   Male  186960

# %%
df.head
# Out:
# <bound method NDFrame.head of          rank discipline  phd  service  gender  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]>

# %%
dates = pd.date_range('1/1/2000', periods=8)

# %%
dates
# Out:
# DatetimeIndex(['2000-01-01', '2000-01-02', '2000-01-03', '2000-01-04',
#                '2000-01-05', '2000-01-06', '2000-01-07', '2000-01-08'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(np.random.randn(8, 4),
   ...:                   index=dates, columns=['A', 'B', 'C', 'D'])

# %%
df
# Out:
#                    A         B         C         D
# 2000-01-01 -1.773054 -0.482608  0.383834  1.260641
# 2000-01-02 -1.840786 -0.895752  0.258420  1.755489
# 2000-01-03 -1.150530 -1.826665  1.399760  0.970889
# 2000-01-04 -1.541044 -1.236283  0.073701 -0.581880
# 2000-01-05 -0.029642  0.800683  0.349849  2.086430
# 2000-01-06  0.506967  0.119162 -1.490858 -0.756199
# 2000-01-07  1.149846 -0.676753  1.151806  0.650457
# 2000-01-08 -0.585878 -0.993452 -1.216904 -1.473194

# %%
df[["rank","salary"]]
# Out:
#          rank  salary
# 0        Prof  186960
# 1        Prof   93000
# 2        Prof  110515
# 3        Prof  131205
# 4        Prof  104800
# ..        ...     ...
# 73       Prof  105450
# 74  AssocProf  104542
# 75       Prof  124312
# 76       Prof  109954
# 77       Prof  109646
#
# [78 rows x 2 columns]

# %%
df[["rank","salary"]][df["gender"]=="Female"]
# Out:
#          rank  salary
# 39       Prof  129000
# 40       Prof  137000
# 41  AssocProf   74830
# 42   AsstProf   80225
# 43   AsstProf   77000
# 44       Prof  151768
# 45       Prof  140096
# 46   AsstProf   74692
# 47  AssocProf  103613
# 48       Prof  111512
# 49       Prof  122960
# 50   AsstProf   97032
# 51       Prof  127512
# 52       Prof  105000
# 53   AsstProf   73500
# 54  AssocProf   62884
# 55   AsstProf   72500
# 56  AssocProf   77500
# 57   AsstProf   72500
# 58       Prof  144651
# 59  AssocProf  103994
# 60   AsstProf   92000
# 61  AssocProf  103750
# 62  AssocProf  109650
# 63       Prof   91000
# 64  AssocProf   73300
# 65       Prof  117555
# 66   AsstProf   63100
# 67       Prof   90450
# 68   AsstProf   77500
# 69       Prof  116450
# 70   AsstProf   78500
# 71  AssocProf   71065
# 72       Prof  161101
# 73       Prof  105450
# 74  AssocProf  104542
# 75       Prof  124312
# 76       Prof  109954
# 77       Prof  109646

# %%
##access phd,rank, salary where rank is prof and gender is male
df[["rank","salary"]][(df["rank"]=="Prof")&(df["gender"]=="Male")]
# Out:
#     rank  salary
# 0   Prof  186960
# 1   Prof   93000
# 2   Prof  110515
# 3   Prof  131205
# 4   Prof  104800
# 5   Prof  122400
# 7   Prof  126300
# 8   Prof   94350
# 9   Prof   57800
# 10  Prof  128250
# 11  Prof  134778
# 13  Prof  162200
# 14  Prof  153750
# 15  Prof  150480
# 18  Prof  107300
# 19  Prof  150500
# 21  Prof  103106
# 24  Prof   91100
# 25  Prof   99418
# 26  Prof  148750
# 27  Prof  155865
# 29  Prof  123683
# 31  Prof  155750
# 32  Prof  103275
# 33  Prof  120000
# 35  Prof  126933
# 36  Prof  146856
# 37  Prof  102000

# %%
df.head
# Out:
# <bound method NDFrame.head of          rank discipline  phd  service  gender  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]>

# %%
df[["rank","salary"]][(df["rank"]=="Prof")&(df["gender"]=="Male")]
# Out:
#     rank  salary
# 0   Prof  186960
# 1   Prof   93000
# 2   Prof  110515
# 3   Prof  131205
# 4   Prof  104800
# 5   Prof  122400
# 7   Prof  126300
# 8   Prof   94350
# 9   Prof   57800
# 10  Prof  128250
# 11  Prof  134778
# 13  Prof  162200
# 14  Prof  153750
# 15  Prof  150480
# 18  Prof  107300
# 19  Prof  150500
# 21  Prof  103106
# 24  Prof   91100
# 25  Prof   99418
# 26  Prof  148750
# 27  Prof  155865
# 29  Prof  123683
# 31  Prof  155750
# 32  Prof  103275
# 33  Prof  120000
# 35  Prof  126933
# 36  Prof  146856
# 37  Prof  102000

# %%
df[["rank","salary"]][(df["rank"]=="Prof")&(df["gender"]=="Male")]
# Out:
#     rank  salary
# 0   Prof  186960
# 1   Prof   93000
# 2   Prof  110515
# 3   Prof  131205
# 4   Prof  104800
# 5   Prof  122400
# 7   Prof  126300
# 8   Prof   94350
# 9   Prof   57800
# 10  Prof  128250
# 11  Prof  134778
# 13  Prof  162200
# 14  Prof  153750
# 15  Prof  150480
# 18  Prof  107300
# 19  Prof  150500
# 21  Prof  103106
# 24  Prof   91100
# 25  Prof   99418
# 26  Prof  148750
# 27  Prof  155865
# 29  Prof  123683
# 31  Prof  155750
# 32  Prof  103275
# 33  Prof  120000
# 35  Prof  126933
# 36  Prof  146856
# 37  Prof  102000

# %%
# Finding Minimum,Maximum,Standard deviation and variance of salary

# %%
df["salary"].mean()
# Out:
# 108023.78205128205

# %%
df["salary"].median()
# Out:
# 104671.0

# %%
df["salary"].std()
# Out:
# 28293.66102226417

# %%
round(df["salary"].mean(),2)
# Out:
# 108023.78

# %%
df["rank"].mode()# finding mode on categorical variable
# Out:
# 0    Prof
# Name: rank, dtype: object

# %%
df["salary"].mode()
# Out:
# 0    92000
# Name: salary, dtype: int64

# %%
df["salary"].var()
# Out:
# 800531254.0427907

# %%
# finding unique values in a column

# %%
df["salary"].unique()
# Out:
# array([186960,  93000, 110515, 131205, 104800, 122400,  81285, 126300,
#         94350,  57800, 128250, 134778,  88000, 162200, 153750, 150480,
#         75044,  92000, 107300, 150500, 103106,  73000,  85000,  91100,
#         99418, 148750, 155865,  91300, 123683, 107008, 155750, 103275,
#        120000, 119800, 126933, 146856, 102000,  91000, 129000, 137000,
#         74830,  80225,  77000, 151768, 140096,  74692, 103613, 111512,
#        122960,  97032, 127512, 105000,  73500,  62884,  72500,  77500,
#        144651, 103994, 103750, 109650,  73300, 117555,  63100,  90450,
#        116450,  78500,  71065, 161101, 105450, 104542, 124312, 109954,
#        109646])

# %%
df["rank"].unique()
# Out:
# array(['Prof', 'AssocProf', 'AsstProf'], dtype=object)

# %%
df["rank"].unique()
# Out:
# array(['Prof', 'AssocProf', 'AsstProf'], dtype=object)

# %%
# Number of unique values
df["salary"].nunique()
# Out:
# 73

# %%
df["rank"].nunique()
# Out:
# 3

# %%
# unique valuee occurence
df["rank"].value_counts()
# Out:
# Prof         46
# AsstProf     19
# AssocProf    13
# Name: rank, dtype: int64

# %%
df["salary"].value_counts()
# Out:
# 92000     3
# 77500     2
# 72500     2
# 91000     2
# 62884     1
#          ..
# 99418     1
# 91100     1
# 85000     1
# 73000     1
# 109646    1
# Name: salary, Length: 73, dtype: int64

# %%
# index based slicing
df.iloc[2:61,2:5]
# Out:
#     phd  service  gender
# 2    23       20    Male
# 3    40       31    Male
# 4    20       18    Male
# 5    20       20    Male
# 6    20       17    Male
# 7    18       18    Male
# 8    29       19    Male
# 9    51       51    Male
# 10   39       33    Male
# 11   23       23    Male
# 12    1        0    Male
# 13   35       33    Male
# 14   25       19    Male
# 15   17        3    Male
# 16    8        3    Male
# 17    4        0    Male
# 18   19        7    Male
# 19   29       27    Male
# 20    4        4    Male
# 21   33       30    Male
# 22    4        2    Male
# 23    2        0    Male
# 24   30       23    Male
# 25   35       31    Male
# 26   38       19    Male
# 27   45       43    Male
# 28    7        2    Male
# 29   21       20    Male
# 30    9        7    Male
# 31   22       21    Male
# 32   27       19    Male
# 33   18       18    Male
# 34   12        8    Male
# 35   28       23    Male
# 36   45       45    Male
# 37   20        8    Male
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of          rank discipline  phd  service  gender  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]>

# %%
df.loc[2:4,3:5]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-152-c04e7bafe19c> in <cell line: 1>()
# ----> 1 df.loc[2:4,3:5]
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1065             if self._is_scalar_access(key):
#    1066                 return self.obj._get_value(*key, takeable=self._takeable)
# -> 1067             return self._getitem_tuple(key)
#    1068         else:
#    1069             # we by definition only have the 0th axis
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_tuple(self, tup)
#    1254             return self._multi_take(tup)
#    1255
# -> 1256         return self._getitem_tuple_same_dim(tup)
#    1257
#    1258     def _get_label(self, label, axis: int):
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexing.py in _getitem_tuple_same_dim(self, tup)
# ...

# %%
df.loc[3:50,["rank","salary"]]
# Out:
#          rank  salary
# 3        Prof  131205
# 4        Prof  104800
# 5        Prof  122400
# 6   AssocProf   81285
# 7        Prof  126300
# 8        Prof   94350
# 9        Prof   57800
# 10       Prof  128250
# 11       Prof  134778
# 12   AsstProf   88000
# 13       Prof  162200
# 14       Prof  153750
# 15       Prof  150480
# 16   AsstProf   75044
# 17   AsstProf   92000
# 18       Prof  107300
# 19       Prof  150500
# 20   AsstProf   92000
# 21       Prof  103106
# 22   AsstProf   73000
# 23   AsstProf   85000
# 24       Prof   91100
# 25       Prof   99418
# 26       Prof  148750
# 27       Prof  155865
# 28   AsstProf   91300
# 29       Prof  123683
# 30  AssocProf  107008
# 31       Prof  155750
# 32       Prof  103275
# 33       Prof  120000
# 34  AssocProf  119800
# 35       Prof  126933
# 36       Prof  146856
# 37       Prof  102000
# 38   AsstProf   91000
# 39       Prof  129000
# 40       Prof  137000
# 41  AssocProf   74830
# 42   AsstProf   80225
# ...

# %%
df.iloc[3:60,2:6]
# Out:
#     phd  service  gender  salary
# 3    40       31    Male  131205
# 4    20       18    Male  104800
# 5    20       20    Male  122400
# 6    20       17    Male   81285
# 7    18       18    Male  126300
# 8    29       19    Male   94350
# 9    51       51    Male   57800
# 10   39       33    Male  128250
# 11   23       23    Male  134778
# 12    1        0    Male   88000
# 13   35       33    Male  162200
# 14   25       19    Male  153750
# 15   17        3    Male  150480
# 16    8        3    Male   75044
# 17    4        0    Male   92000
# 18   19        7    Male  107300
# 19   29       27    Male  150500
# 20    4        4    Male   92000
# 21   33       30    Male  103106
# 22    4        2    Male   73000
# 23    2        0    Male   85000
# 24   30       23    Male   91100
# 25   35       31    Male   99418
# 26   38       19    Male  148750
# 27   45       43    Male  155865
# 28    7        2    Male   91300
# 29   21       20    Male  123683
# ...

# %%
df.iloc[2:4,2:3]# gets the info about the specific row with indexing numbers
# Out:
#    phd
# 2   23
# 3   40

# %%
df.loc[2:3,["phd"]]# gets the info about the specific row with column names
# Out:
#    phd
# 2   23
# 3   40

# %%
#len:length of rows
len(df)
# Out:
# 78

# %%
df.head
# Out:
# <bound method NDFrame.head of          rank discipline  phd  service  gender  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]>

# %%
len(df.loc[2:5,["salary","rank"]])
# Out:
# 4

# %%
len(df.loc[10:50,["phd","salary"]])
# Out:
# 41

# %%
df.loc[10:50,["phd","salary"]]
# Out:
#     phd  salary
# 10   39  128250
# 11   23  134778
# 12    1   88000
# 13   35  162200
# 14   25  153750
# 15   17  150480
# 16    8   75044
# 17    4   92000
# 18   19  107300
# 19   29  150500
# 20    4   92000
# 21   33  103106
# 22    4   73000
# 23    2   85000
# 24   30   91100
# 25   35   99418
# 26   38  148750
# 27   45  155865
# 28    7   91300
# 29   21  123683
# 30    9  107008
# 31   22  155750
# 32   27  103275
# 33   18  120000
# 34   12  119800
# 35   28  126933
# 36   45  146856
# 37   20  102000
# 38    4   91000
# 39   18  129000
# 40   39  137000
# 41   13   74830
# 42    4   80225
# 43    5   77000
# 44   23  151768
# 45   25  140096
# 46   11   74692
# 47   11  103613
# 48   17  111512
# 49   17  122960
# 50   10   97032

# %%
# create a copy and store in df1
df1=df.copy()

# %%
df1
# Out:
#          rank discipline  phd  service  gender  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df2=df.copy()

# %%
df2
# Out:
#          rank discipline  phd  service  gender  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df1.drop(["rank"],axis=1,inplace=True)# error

# %%
df1.head
# Out:
# <bound method NDFrame.head of    discipline  phd  service  gender  salary
# 0           B   56       49    Male  186960
# 1           A   12        6    Male   93000
# 2           A   23       20    Male  110515
# 3           A   40       31    Male  131205
# 4           B   20       18    Male  104800
# ..        ...  ...      ...     ...     ...
# 73          B   18       10  Female  105450
# 74          B   19        6  Female  104542
# 75          B   17       17  Female  124312
# 76          A   28       14  Female  109954
# 77          A   23       15  Female  109646
#
# [78 rows x 5 columns]>

# %%
df1["rank"]# errror due to rank is not there in a vcolumn anymore
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'rank'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df1.drop("salary",axis=1)
# Out:
#    discipline  phd  service  gender
# 0           B   56       49    Male
# 1           A   12        6    Male
# 2           A   23       20    Male
# 3           A   40       31    Male
# 4           B   20       18    Male
# ..        ...  ...      ...     ...
# 73          B   18       10  Female
# 74          B   19        6  Female
# 75          B   17       17  Female
# 76          A   28       14  Female
# 77          A   23       15  Female
#
# [78 rows x 4 columns]

# %%
df1
# Out:
#    discipline  phd  service  gender  salary
# 0           B   56       49    Male  186960
# 1           A   12        6    Male   93000
# 2           A   23       20    Male  110515
# 3           A   40       31    Male  131205
# 4           B   20       18    Male  104800
# ..        ...  ...      ...     ...     ...
# 73          B   18       10  Female  105450
# 74          B   19        6  Female  104542
# 75          B   17       17  Female  124312
# 76          A   28       14  Female  109954
# 77          A   23       15  Female  109646
#
# [78 rows x 5 columns]

# %%
df1.drop("salary",axis=1,inplace=True)

# %%
df1
# Out:
#    discipline  phd  service  gender
# 0           B   56       49    Male
# 1           A   12        6    Male
# 2           A   23       20    Male
# 3           A   40       31    Male
# 4           B   20       18    Male
# ..        ...  ...      ...     ...
# 73          B   18       10  Female
# 74          B   19        6  Female
# 75          B   17       17  Female
# 76          A   28       14  Female
# 77          A   23       15  Female
#
# [78 rows x 4 columns]

# %%
df1
# Out:
#    discipline  phd  service  gender
# 0           B   56       49    Male
# 1           A   12        6    Male
# 2           A   23       20    Male
# 3           A   40       31    Male
# 4           B   20       18    Male
# ..        ...  ...      ...     ...
# 73          B   18       10  Female
# 74          B   19        6  Female
# 75          B   17       17  Female
# 76          A   28       14  Female
# 77          A   23       15  Female
#
# [78 rows x 4 columns]

# %%
# dropping two columns permanently from copyied datasets
df1.drop(["phd","service"],axis =1,inplace =True)

# %%
df1
# Out:
#    discipline  gender
# 0           B    Male
# 1           A    Male
# 2           A    Male
# 3           A    Male
# 4           B    Male
# ..        ...     ...
# 73          B  Female
# 74          B  Female
# 75          B  Female
# 76          A  Female
# 77          A  Female
#
# [78 rows x 2 columns]

# %%
df1
# Out:
#    discipline  gender
# 0           B    Male
# 1           A    Male
# 2           A    Male
# 3           A    Male
# 4           B    Male
# ..        ...     ...
# 73          B  Female
# 74          B  Female
# 75          B  Female
# 76          A  Female
# 77          A  Female
#
# [78 rows x 2 columns]

# %%
#row wise deletion, axis=0

df.drop(index=4,axis=0,inplace=True)

# %%
df
# Out:
#          rank discipline  gender  salary
# 0        Prof          B    Male  186960
# 1        Prof          A    Male   93000
# 2        Prof          A    Male  110515
# 3        Prof          A    Male  131205
# 5        Prof          A    Male  122400
# ..        ...        ...     ...     ...
# 73       Prof          B  Female  105450
# 74  AssocProf          B  Female  104542
# 75       Prof          B  Female  124312
# 76       Prof          A  Female  109954
# 77       Prof          A  Female  109646
#
# [77 rows x 4 columns]

# %%
df1.drop(index=8,axis=0,inplace=True)

# %%
df1
# Out:
#    discipline  gender
# 0           B    Male
# 1           A    Male
# 2           A    Male
# 3           A    Male
# 4           B    Male
# ..        ...     ...
# 73          B  Female
# 74          B  Female
# 75          B  Female
# 76          A  Female
# 77          A  Female
#
# [77 rows x 2 columns]

# %%
df1.iloc[7:11,1:5]# here you wont be able to see row 8
# Out:
#    gender
# 7    Male
# 9    Male
# 10   Male
# 11   Male

# %%
# check for missing values

# %%
df.isna()
# Out:
#      rank  discipline  gender  salary
# 0   False       False   False   False
# 1   False       False   False   False
# 2   False       False   False   False
# 3   False       False   False   False
# 5   False       False   False   False
# ..    ...         ...     ...     ...
# 73  False       False   False   False
# 74  False       False   False   False
# 75  False       False   False   False
# 76  False       False   False   False
# 77  False       False   False   False
#
# [77 rows x 4 columns]

# %%
df.isna().sum()# column wise count missing values
# Out:
# rank          0
# discipline    0
# gender        0
# salary        0
# dtype: int64

# %%
#drop records/rows having missing values
df.dropna(inplace=True)

# %%
df
# Out:
#          rank discipline  gender  salary
# 0        Prof          B    Male  186960
# 1        Prof          A    Male   93000
# 2        Prof          A    Male  110515
# 3        Prof          A    Male  131205
# 5        Prof          A    Male  122400
# ..        ...        ...     ...     ...
# 73       Prof          B  Female  105450
# 74  AssocProf          B  Female  104542
# 75       Prof          B  Female  124312
# 76       Prof          A  Female  109954
# 77       Prof          A  Female  109646
#
# [77 rows x 4 columns]

# %%
#drop duplicates
df.drop_duplicates(inplace=True)
